# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Data set topic --> Finance
# Source -->
# Describtion of data :
# ->
# ->
# ->
# ->

# %%
try:
  # Try reading the full CSV file
  df = pd.read_csv('inflation.csv')

except Exception as e:
  # Catch any exception and display error
  print('Error:', e)

  # Try again with error handling 
  df = pd.read_csv('inflation.csv', error_bad_lines=False)

# Check result
print(df.shape) 

# Optionally reset index if rows are misaligned
df = df.reset_index(drop=True)

print(df.shape)
# Out:
# Error: Error tokenizing data. C error: Expected 3 fields in line 5, saw 68
#
# (1, 3)
# (1, 3)
# C:\Users\mahmo\AppData\Local\Temp\ipykernel_24704\1057101809.py:10: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv('inflation.csv', error_bad_lines=False)
# Skipping line 5: expected 3 fields, saw 68
# Skipping line 6: expected 3 fields, saw 68
# Skipping line 7: expected 3 fields, saw 68
# Skipping line 8: expected 3 fields, saw 68
# Skipping line 9: expected 3 fields, saw 68
# Skipping line 10: expected 3 fields, saw 68
# Skipping line 11: expected 3 fields, saw 68
# Skipping line 12: expected 3 fields, saw 68
# Skipping line 13: expected 3 fields, saw 68
# Skipping line 14: expected 3 fields, saw 68
# Skipping line 15: expected 3 fields, saw 68
# Skipping line 16: expected 3 fields, saw 68
# Skipping line 17: expected 3 fields, saw 68
# ...

# %%
df.head()
df.shape
df.columns
df.dtypes
# Out:
# Data Source                      object
# World Development Indicators     object
# Unnamed: 2                      float64
# dtype: object

# %%
df.describe()
# Out:
#        Unnamed: 2
# count         0.0
# mean          NaN
# std           NaN
# min           NaN
# 25%           NaN
# 50%           NaN
# 75%           NaN
# max           NaN

# %%
df.isnull().sum()
# Out:
# Data Source                     0
# World Development Indicators    0
# Unnamed: 2                      1
# dtype: int64

# %%
# Plot histogram of a column 
df['Inflation, GDP deflator (annual %)'].plot.hist()
df['Inflation, GDP deflator (annual %)'].plot.hist()
col_name = 'Inflation, GDP deflator (annual %)'
df[col_name].plot.hist()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...
